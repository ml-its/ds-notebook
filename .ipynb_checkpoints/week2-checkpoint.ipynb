# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.its.ac.id/matematika/dosen-staf/daftar-dosen/'
req = requests.get(url)
print(req.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>Daftar Dosen - Departemen Matematika</title>
#     <meta property="og:image" content="https://www.its.ac.id/matematika/wp-content/themes/DepartmentITS/assets/img/header-image-default.jpg" />
#     <link rel="shortcut icon" href="https://www.its.ac.id/matematika/wp-content/themes/DepartmentITS/assets/img/favicon.png">
#
# <!-- This site is optimized with the Yoast SEO plugin v8.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <link rel="canonical" href="https://www.its.ac.id/matematika/dosen-staf/daftar-dosen/" />
# <meta property="og:locale" content="id_ID" />
# <meta property="og:locale:alternate" content="en_US" />
# <meta property="og:type" content="article" />
# <meta property="og:title" content="Daftar Dosen - Departemen Matematika" />
# ...

# %%
soup = BeautifulSoup(req.text, 'lxml')
soup.link
# Out:
# <link href="https://www.its.ac.id/matematika/wp-content/themes/DepartmentITS/assets/img/favicon.png" rel="shortcut icon"/>

# %%
semua_gambar = soup.find_all('img',{'class':'vc_single_image-img attachment-medium'})

# %%
for dosen in semua_gambar: 
    print(dosen, '\n')
# Out:
# <img alt="" class="vc_single_image-img attachment-medium" height="300" sizes="(max-width: 214px) 100vw, 214px" src="https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/subiono-214x300.jpg" srcset="https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/subiono-214x300.jpg 214w, https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/subiono-228x320.jpg 228w, https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/subiono.jpg 506w" width="214"/>
#
# ...

# %%
for dosen in semua_gambar:
    print(dosen['src'])
# Out:
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/subiono-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/yunus-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/komar1-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/rinurwati-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/ngurah-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/iis-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/wahyu1-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/sadjidon-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/erna-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/sunarsini-214x300.jpg
# https://www.its.ac.id/matematika/wp-content/uploads/sites/42/2018/08/didik-214x300.jpg
# ...

# %%
url = 'https://www.olx.co.id/all-results/q-mobil/'
req_paperwhite = requests.get(url)
soup_paperwhite = BeautifulSoup(req_paperwhite.text, 'lxml')

# %%
seluruh_judul= soup_paperwhite.find_all('a', {'class':'marginright5 link linkWithHash detailsLink'})

# %%
for paperwhite in seluruh_judul: 
    print(paperwhite['href'])
# Out:
# https://www.olx.co.id/iklan/mobil-baru-mitsubishi-xpander-2019-dp-super-murah-atau-angsuran-super-minim-IDzlhR3.html?ad_type=HL#61eafb9342;promoted
# https://www.olx.co.id/iklan/gps-pelacak-mobil-sadap-suara-free-peta-monitoring-mobil-bergaransi-IDz2x1R.html?ad_type=HL#61eafb9342;promoted
# https://www.olx.co.id/iklan/carteran-mobil-barang-bak-box-pickup-engkel-truk-colt-diesel-IDyWuNH.html?ad_type=HL#61eafb9342;promoted
# https://www.olx.co.id/iklan/buana-mandiri-jogja-tempat-sewa-mobil-IDzyTkj.html?ad_type=OR#61eafb9342
# https://www.olx.co.id/iklan/sewa-mobil-buana-mandiri-trans-lepas-kunci-IDzyTiO.html?ad_type=OR#61eafb9342
# https://www.olx.co.id/iklan/mobil-honda-crv-2-4-IDzyTik.html?ad_type=OR#61eafb9342
# https://www.olx.co.id/iklan/mobil-baru-honda-hrv-new-promo-special-lebaran-2019-IDzyTgu.html?ad_type=OR#61eafb9342;promoted
# https://www.olx.co.id/iklan/rumah-masuk-mobil-hrg-mulai-65jtan-bebas-banjir-IDzufA4.html?ad_type=OR#61eafb9342
# ...

# %%
seluruh_harga = soup_paperwhite.find_all('strong', class_='c000')

# %%
for price in seluruh_harga: 
    print(price.text.strip())
# Out:
# Rp 256.400.000
# Rp 500.000
# Rp 75.000
# Rp 200.000
# Rp 200.000
# Rp 160.000.000
# Rp 304.300.000
# Rp 65.000.000
# Rp 11.500.000
# Rp 4.200.000
# Rp 4.200.000
# Rp 80.000
# Rp 2.800.000
# Rp 280.000
# Rp 5.500.000
# dari Rp 10.000ke Rp 13.000
# Rp 11.500.000
# Rp 5.300.000
# Rp 280.000

# %%
seluruh_kota = soup_paperwhite.find_all('p', class_='color-9 lheight14 margintop3')
seluruh_kota
# Out:
# [<p class="color-9 lheight14 margintop3">
#  <small class="breadcrumb small">
#                                                                      Mobil Bekas » Mitsubishi
#  <span>Jakarta Timur</span> </small>
#  </p>, <p class="color-9 lheight14 margintop3">
#  <small class="breadcrumb small">
#                                                                      Mobil » Aksesoris
#  <label class="icon-bekas">Baru</label><br/>
#  <span>Medan Kota</span> </small>
#  </p>, <p class="color-9 lheight14 margintop3">
#  <small class="breadcrumb small">
#                                                                      Jasa » Rental Mobil &amp; Motor
#  <span>Surabaya Kota</span> </small>
#  </p>, <p class="color-9 lheight14 margintop3">
#  <small class="breadcrumb small">
#                                                                      Jasa » Rental Mobil &amp; Motor
#  <span>Yogyakarta Kota</span> </small>
#  </p>, <p class="color-9 lheight14 margintop3">
# ...

# %%
for city in seluruh_kota: 
    print(city.find('span').text)
# Out:
# Jakarta Timur
# Medan Kota
# Surabaya Kota
# Yogyakarta Kota
# Yogyakarta Kota
# Bekasi Kota
# Jakarta Timur
# Bandung Kab.
# Jakarta Utara
# Tangerang Selatan Kota
# Tangerang Selatan Kota
# Sleman Kab.
# Banggai Kab.
# Palembang Kota
# Cirebon Kota
# Palembang Kota
# Jakarta Utara
# Denpasar Kota
# Musi Rawas Kab.

# %%
seluruh_tanggal = soup_paperwhite.find_all('td',class_='rel tcenter')

# %%
for date in seluruh_tanggal: 
    print(date.text.strip())
# Out:
# 19  Apr
# 12  Apr
# 7  Mar
# 09:41
# 09:41
# 09:41
# 09:40
# 09:40
# 09:37
# 09:37
# 09:37
# 09:37
# 09:36
# 09:36
# 09:36
# 09:36
# 09:36
# 09:36
# 09:35

# %%
[seluruh_judul, seluruh_harga, seluruh_tanggal, seluruh_kota]
print(f'panjang seluruh judul: {len(seluruh_judul)}\n panjang seluruh harga: {len(seluruh_harga)}\n panjang seluruh tanggal: {len(seluruh_tanggal)}\n panjang seluruh kota: {len(seluruh_kota)}')
# Out:
# panjang seluruh judul: 19
#  panjang seluruh harga: 19
#  panjang seluruh tanggal: 19
#  panjang seluruh kota: 19

# %%
paperwhite = []
for judul, harga, tanggal, kota in zip(seluruh_judul, seluruh_harga, seluruh_tanggal, seluruh_kota):
    item = {}
    print(judul.text.strip())
    item['judul']=judul.text.strip()
    print(harga.text.strip())
    item['harga'] = harga.text.strip()
    print(tanggal.text.strip())
    item['tanggal'] = tanggal.text.strip()
    print(kota.find('span').text.strip())
    item['kota'] = kota.find('span').text.strip()
    paperwhite.append(item)
# Out:
# [Mobil Baru] Mitsubishi Xpander 2019. DP SUPER MURAH ATAU ANGSURAN SUPER MINIM
# Rp 256.400.000
# 19  Apr
# Jakarta Timur
# GPS Pelacak mobil sadap suara free peta monitoring mobil bergaransi
# Rp 500.000
# 12  Apr
# Medan Kota
# Carteran Mobil Barang (Bak / Box) Pickup / Engkel / Truk Colt Diesel
# Rp 75.000
# 7  Mar
# Surabaya Kota
# Buana mandiri jogja tempat sewa mobil
# Rp 200.000
# 09:41
# Yogyakarta Kota
# sewa mobil Buana Mandiri trans lepas kunci
# Rp 200.000
# 09:41
# Yogyakarta Kota
# Mobil Honda CRV 2.4
# Rp 160.000.000
# 09:41
# Bekasi Kota
# [Mobil Baru] Honda HRV New PROMO SPECIAL LEBARAN 2019
# Rp 304.300.000
# 09:40
# Jakarta Timur
# rumah masuk mobil hrg mulai 65jtan bebas banjir
# Rp 65.000.000
# 09:40
# Bandung Kab.
# velg mobil TRD fortuner ring 22
# Rp 11.500.000
# 09:37
# Jakarta Utara
# velg mobil Mazda BT50 tipe SAHARA JT9027 HSR R15X8 H6X139,7 ET8 BMF
# Rp 4.200.000
# 09:37
# Tangerang Selatan Kota
# ...

# %%
paperwhite
# Out:
# [{'judul': '[Mobil Baru] Mitsubishi Xpander 2019. DP SUPER MURAH ATAU ANGSURAN SUPER MINIM',
#   'harga': 'Rp 256.400.000',
#   'tanggal': '19  Apr',
#   'kota': 'Jakarta Timur'},
#  {'judul': 'GPS Pelacak mobil sadap suara free peta monitoring mobil bergaransi',
#   'harga': 'Rp 500.000',
#   'tanggal': '12  Apr',
#   'kota': 'Medan Kota'},
#  {'judul': 'Carteran Mobil Barang (Bak / Box) Pickup / Engkel / Truk Colt Diesel',
#   'harga': 'Rp 75.000',
#   'tanggal': '7  Mar',
#   'kota': 'Surabaya Kota'},
#  {'judul': 'Buana mandiri jogja tempat sewa mobil',
#   'harga': 'Rp 200.000',
#   'tanggal': '09:41',
#   'kota': 'Yogyakarta Kota'},
#  {'judul': 'sewa mobil Buana Mandiri trans lepas kunci',
#   'harga': 'Rp 200.000',
#   'tanggal': '09:41',
#   'kota': 'Yogyakarta Kota'},
#  {'judul': 'Mobil Honda CRV 2.4',
#   'harga': 'Rp 160.000.000',
#   'tanggal': '09:41',
#   'kota': 'Bekasi Kota'},
#  {'judul': '[Mobil Baru] Honda HRV New PROMO SPECIAL LEBARAN 2019',
# ...

# %%
paperwhite[-1]
# Out:
# {'judul': 'Selimut mobil h2r bandung bahan kualitas halus7',
#  'harga': 'Rp 280.000',
#  'tanggal': '09:35',
#  'kota': 'Musi Rawas Kab.'}

# %%
type(paperwhite)
# Out:
# list

# %%
import pandas as pd

# %%
df = pd.DataFrame(paperwhite)

# %%
df
# Out:
#                          harga  \
# 0               Rp 256.400.000
# 1                   Rp 500.000
# 2                    Rp 75.000
# 3                   Rp 200.000
# 4                   Rp 200.000
# 5               Rp 160.000.000
# 6               Rp 304.300.000
# 7                Rp 65.000.000
# 8                Rp 11.500.000
# 9                 Rp 4.200.000
# 10                Rp 4.200.000
# 11                   Rp 80.000
# 12                Rp 2.800.000
# 13                  Rp 280.000
# 14                Rp 5.500.000
# 15  dari Rp 10.000ke Rp 13.000
# 16               Rp 11.500.000
# 17                Rp 5.300.000
# 18                  Rp 280.000
#
#                                                 judul                    kota  \
# 0   [Mobil Baru] Mitsubishi Xpander 2019. DP SUPER...           Jakarta Timur
# 1   GPS Pelacak mobil sadap suara free peta monito...              Medan Kota
# 2   Carteran Mobil Barang (Bak / Box) Pickup / Eng...           Surabaya Kota
# ...

# %%
df.to_csv('olx.csv')

# %%
seluruh_page = soup_paperwhite.find_all('span', {'class':'item inline-block'})

# %%
terakhir = seluruh_page[-1].a
terakhir
# Out:
# <a class="block br3 brc8 large tdnone lheight24" href="https://www.olx.co.id/all-results/q-mobil/?page=500">
# <span>500</span>
# </a>

# %%
terakhir = int(terakhir['href'].split('=')[-1])
terakhir
# Out:
# 500

# %%
kumpulan_link_mobil = []
url_mobil = 'https://www.olx.co.id/all-results/q-mobil/?page={}'
print(url.format('5'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-c1646858515b> in <module>
#       1 kumpulan_link_mobil = []
#       2 url_mobil = 'https://www.olx.co.id/all-results/q-mobil/?page={}'
# ----> 3 print(url.format('5'))
#
# IndexError: tuple index out of range

# %%
for page in range(1,int(terakhir)): 
    kumpulan_link_mobil.append(url_mobil.format(page))

# %%
kumpulan_link_mobil
# Out:
# ['https://www.olx.co.id/all-results/q-mobil/?page=0',
#  'https://www.olx.co.id/all-results/q-mobil/?page=1',
#  'https://www.olx.co.id/all-results/q-mobil/?page=2',
#  'https://www.olx.co.id/all-results/q-mobil/?page=3',
#  'https://www.olx.co.id/all-results/q-mobil/?page=4',
#  'https://www.olx.co.id/all-results/q-mobil/?page=5',
#  'https://www.olx.co.id/all-results/q-mobil/?page=6',
#  'https://www.olx.co.id/all-results/q-mobil/?page=7',
#  'https://www.olx.co.id/all-results/q-mobil/?page=8',
#  'https://www.olx.co.id/all-results/q-mobil/?page=9',
#  'https://www.olx.co.id/all-results/q-mobil/?page=10',
#  'https://www.olx.co.id/all-results/q-mobil/?page=11',
#  'https://www.olx.co.id/all-results/q-mobil/?page=12',
#  'https://www.olx.co.id/all-results/q-mobil/?page=13',
#  'https://www.olx.co.id/all-results/q-mobil/?page=14',
#  'https://www.olx.co.id/all-results/q-mobil/?page=15',
#  'https://www.olx.co.id/all-results/q-mobil/?page=16',
# ...
